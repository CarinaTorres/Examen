# %%
from IPython.utils.text import columnize
#Listado de clientes
clientes = []
#Listado de Departamentos disponibles
DepartamentosDisponibles = [
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
    ["[ ]","[ ]" ,"[ ]" , "[ ]"],
]
#Listado Detalle Departamento
DepartamentosDetalle = [
    {"Tipo": 1, "precio": "$3800 UF "},
    {"Tipo": 2, "precio": "$3000 UF"},
    {"Tipo": 3, "precio": "$2800 UF"},
    {"Tipo": 4, "precio": "$3500 UF"},


]

# Opción menú 1
def ver_disponibilidad_Departamentos():
  for i in range(len(DepartamentosDisponibles)):
    for j in range(len(DepartamentosDisponibles[i])):
      if DepartamentosDisponibles[i][j]  == "[ ]":
                print("[ ]", end=" ")
      else:
                print("[X]", end=" ")
    print()


def seleccionar_Departamentos():

#Datos Cliente
    print("--INGRESAR DATOS CLIENTE--")
    nombre = input("Nombre completo: ")
    rut = input("RUT: ")
    telefono = input("Ingrese su teléfono: ")


#Seleccion Departamento
    fila = int(input("Ingrese el piso del departamento: "))
    col = int(input("Ingrese el número del departamento: "))
    fila-=1
    col-=1

    if fila < 0 or fila >= len(DepartamentosDisponibles) or col < 0 or col >= len(DepartamentosDisponibles[0]):
        print("Coordenadas inválidas, porfavor intente nuevamente")
        return

    if DepartamentosDisponibles[fila][col] == "[ ]":
        DepartamentosDisponibles[fila][col] = "[X]"
        dataLote = {"Piso": fila, "Número": col, "rut": rut, "nombre": nombre, "telefono": telefono }
        clientes.append(dataLote)
        print("Departamento seleccionado con éxito.")
    else:
        print("El Departamento seleccionado no está disponible.")

def mostrar_clientes():
    if len(clientes) == 0:
        print("No existen Clientes Registrados Aun.")
        return

        print("Clientes registrados:")
        for cliente in cliente:
            print(f"RUT: {cliente['rut']}")
            print(f"Nombre: {cliente['nombre']}")
            print(f"Teléfono: {cliente['telefono']}")
            print()

def mostrar_ganancias(Tipo_1, Tipo_2, Tipo_3, Tipo_4):
  precio_1 = 3800
  precio_2 = 3000
  precio_3 = 2800
  precio_4 = 3500

  ganancias_precio_1 = Tipo_1 * Tipo_1
  ganancias_precio_2 = Tipo_2 * Tipo_2
  ganancias_precio_3 = Tipo_3 * Tipo_3
  ganancias_precio_4 = Tipo_4 * Tipo_4

  if (ganancias) == 0:
    print ("No hay ganancias ingresadas ", ganancias)

    for ganancias in ganancias:
         ganancias_totales = ganancias_precio_1 + ganancias_precio_2 + ganancias_precio_3 + ganancias_precio_4
  return ganancias_totales
  ganancias = Calcular_ganancias (precio_1_vendidos, precio_2_vendidos, precio_3_vendidos, precio_4_vendidos)
  print ("Las ganancias totales son: ", ganancias)

while (True):
    print("----- Casa Feliz -----")
    print("1. Mostrar Departamentos disponibles ")
    print("2. Comprar Departamento")
    print("3. Ver listado de compradores")
    print("4. mostrar ganancias totales")
    print("5. Salir")

    opcion = int(input("Seleccione una opción: "))

    if opcion == 1:
        ver_disponibilidad_Departamentos()
    if opcion == 2:
        seleccionar_Departamentos()
    if opcion == 3:
        mostrar_clientes()
    if opcion == 4:
      mostrar_ganancias()
    if opcion == 5:
        print("Adios, Muchas Gracias")
        break;
    if opcion < 1 | opcion > 5:
        print("Menú seleccionado no existe, intente nuevamente")
# Out:
# ----- Casa Feliz -----
# 1. Mostrar Departamentos disponibles
# 2. Comprar Departamento
# 3. Ver listado de compradores
# 4. mostrar ganancias totales
# 5. Salir
# No existen Clientes Registrados Aun.
# ----- Casa Feliz -----
# 1. Mostrar Departamentos disponibles
# 2. Comprar Departamento
# 3. Ver listado de compradores
# 4. mostrar ganancias totales
# 5. Salir
# --INGRESAR DATOS CLIENTE--
# Departamento seleccionado con éxito.
# ----- Casa Feliz -----
# 1. Mostrar Departamentos disponibles
# 2. Comprar Departamento
# 3. Ver listado de compradores
# 4. mostrar ganancias totales
# 5. Salir
# ----- Casa Feliz -----
# 1. Mostrar Departamentos disponibles
# 2. Comprar Departamento
# 3. Ver listado de compradores
# 4. mostrar ganancias totales
# 5. Salir
# Seleccione una opción: 5
# Adios, Muchas Gracias
